# %% [markdown]
# http://insightsoftwareconsortium.github.io/SimpleITK-Notebooks/

# %%
import SimpleITK as sitk
print(sitk.Version())
# Out:
# SimpleITK Version: 1.0.0 (ITK 4.11)
# Compiled: Apr  7 2017 14:24:35

# %%
from downloaddata import fetch_data, fetch_data_all

# %%
#https://matplotlib.org/users/image_tutorial.html
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def show(img):
    a = sitk.GetArrayFromImage(img)
    plt.imshow(a, cmap='gray')

# %%
fetch_data("cthead1.png", cache_directory_name='Data')
img = sitk.ReadImage('Data/cthead1.png')
img = sitk.Cast(img, sitk.sitkFloat32)
show(img)
# Out:
# Fetching cthead1.png
# Downloaded 29351 of 29351 bytes (100.00%)

# %%
def sitk_show(img, title=None, margin=0.0, dpi=40):
    nda = sitk.GetArrayFromImage(img)
    spacing = img.GetSpacing()
    print(spacing)
    print(nda.shape)
    figsize = (1 + margin) * nda.shape[0] / dpi, (1 + margin) * nda.shape[1] / dpi

    extent = (0, nda.shape[1] * spacing[1], nda.shape[0] * spacing[0], 0)
   
    fig = plt.figure(figsize=figsize, dpi=dpi)
    ax = fig.add_axes([margin, margin, 1 - 2*margin, 1 - 2*margin])
    
    plt.set_cmap("gray")
    ax.imshow(nda, extent=extent, interpolation=None)
    
    if title:
        plt.title(title)
    
    plt.show()

# %%
sitk_show(img, "the image")
# Out:
# (1.0, 1.0)
# (256, 256)
